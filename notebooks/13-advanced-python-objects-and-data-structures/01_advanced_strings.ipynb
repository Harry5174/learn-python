# %% [markdown]
# ## Advanced strings

# %%
s = 'Hello world'

# %%
s.capitalize()
# Out:
# 'Hello world'

# %%
s.upper()
# Out:
# 'HELLO WORLD'

# %%
s.lower()
# Out:
# 'hello world'

# %%
s.count('o')
# Out:
# 2

# %%
s.find('o')
# Out:
# 4

# %%
s
# Out:
# 'Hello world'

# %%
s.center(20,'z')
# Out:
# 'zzzzHello worldzzzzz'

# %%
'hello\thi'.expandtabs()
# Out:
# 'hello   hi'

# %%
s = 'hello'

# %%
s.isalnum()
# Out:
# True

# %%
s.isalpha()
# Out:
# True

# %%
s.islower()
# Out:
# True

# %%
s
# Out:
# 'hello'

# %%
s.isspace()
# Out:
# False

# %%
s.istitle()
# Out:
# False

# %%
s.isupper()
# Out:
# False

# %%
s.endswith('lo')
# Out:
# True

# %%
s.split('e')
# Out:
# ['h', 'llo']

# %%
s = 'hihihihihhhiihihih'

# %%
s.split('i')
# Out:
# ['h', 'h', 'h', 'h', 'hhh', '', 'h', 'h', 'h']

# %%
s.partition('i')
# Out:
# ('h', 'i', 'hihihihhhiihihih')
