# %% [markdown]
# ## Advanced sets

# %%
s = set()

# %%
s.add(1)

# %%
s.add(2)

# %%
s
# Out:
# {1, 2}

# %%
s.add(2)

# %%
s
# Out:
# {1, 2}

# %%
s.clear()

# %%
s
# Out:
# set()

# %%
s = {1,2,3}

# %%
sc = s.copy()

# %%
s.add(4)

# %%
s
# Out:
# {1, 2, 3, 4}

# %%
sc
# Out:
# {1, 2, 3}

# %%
s.difference(sc) # returns difference
# Out:
# {4}

# %%
s1 = {1,2,3}

# %%
s2 = {1,4,5}

# %%
s1.difference_update(s2)

# %%
s1
# Out:
# {2, 3}

# %%
s
# Out:
# {1, 2, 3, 4}

# %%
s.discard(2)

# %%
s
# Out:
# {1, 3, 4}

# %%
s.discard(12)

# %%
s
# Out:
# {1, 3, 4}

# %%
s1.add(1)
s1
# Out:
# {1, 2, 3}

# %%
s2.add(1)
s2
# Out:
# {1, 4, 5}

# %%
s1.intersection(s2)
# Out:
# {1}

# %%
s1
# Out:
# {1, 2, 3}

# %%
s1.intersection_update(s2)

# %%
s1
# Out:
# {1}

# %%
# many more methods are available
