# %% [markdown]
# ## Python Debugger (trace)

# %%
import pdb

# %%
x = [1,2,3,4]

y = 2
z = 3

result_one = y + z

pdb.set_trace()
result_two = y + x # debugging this error
# Out:
# > /tmp/ipykernel_247279/39362239.py(8)<module>()
#       5
#       6 result_one = y + z
#       7
# ----> 8 pdb.set_trace()
#       9 result_two = y + x
#
# [1, 2, 3, 4]
# 2
# [1, 2, 3, 4]
# 2
# 3
# 3
# 3
# 3
# 3
# 3
# *** TypeError: can only concatenate list (not "int") to list
# 5
# 5
# 5
# 5
# 5
# 5
# 5
# --KeyboardInterrupt--
#
# KeyboardInterrupt: Interrupted by user
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 9
#       5
#       6 result_one = y + z
#       7
#       8 pdb.set_trace()
# ----> 9 result_two = y + x
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'
