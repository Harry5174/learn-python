# %%
pwd
# Out:
# '/home/harry/Desktop/prcx_01/xx_github/learn-python/notebooks/10-advanced-python-modules'

# %%
f = open('practice.txt', 'w+')
f.write('This is a test string')
f.close()

# %%
import os

# %%
os.getcwd()
# Out:
# '/home/harry/Desktop/prcx_01/xx_github/learn-python/notebooks/10-advanced-python-modules'

# %%
os.listdir() # you can input path of the directory you want list of items for
# Out:
# ['00_python_collections_module.ipynb',
#  'practice.txt',
#  '01_opening_reading_files_folders.ipynb']

# %%
import shutil

# %%
# shutil.move('practice.txt', '/home/harry/Desktop/') # moves the file to Desktop

# %%
os.unlink # deletes a file at path you provide
os.rmdir # deletes a folder (folder must be empyt) at the path you provide
shutil.rmtree # this is the most dangerous, it will remove files and folders contained in a path. (all these methods cannot be reversed)
# import send2trash # sends data to trash bin
