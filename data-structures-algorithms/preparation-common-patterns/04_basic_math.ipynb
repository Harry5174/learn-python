# %% [markdown]
# # Prime Number
#
# ## Problem Statement
#
# Given an integer `n`, return `true` if `n` is a prime number, otherwise return `false`.
#
# A prime number is a number greater than `1` that has exactly two factors:
#
# - `1`
# - itself
#
# ---
#
# ## Examples
#
# ### Example 1
#
# Input:
# n = 7
#
# Output:
# true
#
# Explanation:
# 7 has only two factors: 1 and 7.
#
# ---
#
# ### Example 2
#
# Input:
# n = 10
#
# Output:
# false
#
# Explanation:
# 10 is divisible by 2 and 5.
#
# ---
#
# ### Example 3
#
# Input:
# n = 1
#
# Output:
# false
#
# Explanation:
# 1 is not a prime number.
#
# ---
#
# ### Example 4
#
# Input:
# n = 2
#
# Output:
# true
#
# Explanation:
# 2 is the smallest prime number.
#
# ---
#
# ## Constraints
#
# - `-10^9 <= n <= 10^9`
#
# ---
#
# ## Expected Complexity
#
# - Time Complexity: `O(sqrt(n))`
# - Space Complexity: `O(1)`

# %%
import math

class Solution:
    def is_prime(self, n):
        if n <= 1:
            return False
        if n <= 3:
            return True
        if n%2 == 0 or n%3 == 0:
            return False
        
        limit = int(math.sqrt(n)) + 1
        
        for x in range(5, limit, 6):
            if n%x == 0 or n%(x + 2) == 0:
                return False
            
        return True

# %% [markdown]
# # Factorial
#
# ## Problem Statement
#
# Given a non-negative integer `n`, return the factorial of `n`.
#
# The factorial of a number `n` is the product of all positive integers from `1` to `n`.
#
# It is represented as:
#
# n! = n × (n - 1) × (n - 2) × ... × 1
#
# Special case:
#
# 0! = 1
#
# ---
#
# ## Examples
#
# ### Example 1
#
# Input:
# n = 5
#
# Output:
# 120
#
# Explanation:
# 5! = 5 × 4 × 3 × 2 × 1 = 120
#
# ---
#
# ### Example 2
#
# Input:
# n = 0
#
# Output:
# 1
#
# Explanation:
# 0! is defined as 1.
#
# ---
#
# ### Example 3
#
# Input:
# n = 3
#
# Output:
# 6
#
# Explanation:
# 3! = 3 × 2 × 1 = 6
#
# ---
#
# ## Constraints
#
# - `0 <= n <= 20`
#
# ---
#
# ## Expected Complexity
#
# - Time Complexity: `O(n)`
# - Space Complexity: `O(1)` for iterative solution

# %%
class Solution:
    def factorial(self, n: int) -> int:
        result = 1

        for i in range(1, n + 1):
            result *= i

        return result

# %% [markdown]
# # Fibonacci Number
#
# ## Problem Statement
#
# Given an integer `n`, return the `n`th Fibonacci number.
#
# The Fibonacci sequence is defined as:
#
# F(0) = 0
# F(1) = 1
#
# For `n > 1`:
#
# F(n) = F(n - 1) + F(n - 2)
#
# ---
#
# ## Examples
#
# ### Example 1
#
# Input:
# n = 2
#
# Output:
# 1
#
# Explanation:
# F(2) = F(1) + F(0) = 1 + 0 = 1
#
# ---
#
# ### Example 2
#
# Input:
# n = 3
#
# Output:
# 2
#
# Explanation:
# F(3) = F(2) + F(1) = 1 + 1 = 2
#
# ---
#
# ### Example 3
#
# Input:
# n = 4
#
# Output:
# 3
#
# Explanation:
# F(4) = F(3) + F(2) = 2 + 1 = 3
#
# ---
#
# ### Example 4
#
# Input:
# n = 0
#
# Output:
# 0
#
# ---
#
# ## Constraints
#
# - `0 <= n <= 30`
#
# ---
#
# ## Expected Complexity
#
# - Time Complexity: `O(n)`
# - Space Complexity: `O(1)`

# %%
class Solution:
    def fibonacci(self, n):
        if n == 0:
            return 0
        elif n == 1:
            return 1
        
        a, b = 0, 1
        for _ in range(2, n + 1):
            a, b = b, a + b
        
        return b

# %% [markdown]
# # Sum of Digits
#
# ## Problem Statement
#
# Given a non-negative integer `n`, return the sum of its digits.
#
# You should solve this using basic mathematical operations, not by converting the number into a string.
#
# ---
#
# ## Examples
#
# ### Example 1
#
# Input:
# n = 123
#
# Output:
# 6
#
# Explanation:
# 1 + 2 + 3 = 6
#
# ---
#
# ### Example 2
#
# Input:
# n = 405
#
# Output:
# 9
#
# Explanation:
# 4 + 0 + 5 = 9
#
# ---
#
# ### Example 3
#
# Input:
# n = 0
#
# Output:
# 0
#
# Explanation:
# The sum of digits of 0 is 0.
#
# ---
#
# ### Example 4
#
# Input:
# n = 9999
#
# Output:
# 36
#
# Explanation:
# 9 + 9 + 9 + 9 = 36
#
# ---
#
# ## Constraints
#
# - `0 <= n <= 10^9`
#
# ---
#
# ## Expected Complexity
#
# - Time Complexity: `O(d)`
# - Space Complexity: `O(1)`
#
# Where `d` is the number of digits in `n`.
