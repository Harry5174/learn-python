# %% [markdown]
# # Problem: Add Two Numbers
#
# ## Link
# https://leetcode.com/problems/add-two-numbers/

# %%
# Solution
# Definition for singly-linked list.
class ListNode(object):
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
        
class Solution(object):
    def addTwoNumbers(self, l1, l2):
        """
        :type l1: Optional[ListNode]
        :type l2: Optional[ListNode]
        :rtype: Optional[ListNode]
        """
        dummy = ListNode()
        carry = 0
        current = dummy
        
        while l1 or l2 or carry:
            val1 = l1.val if l1 else 0
            val2 = l2.val if l2 else 0
            
            total  = val1 + val2 + carry
            carry = total // 10
            digit = total % 10
            
            current.next = ListNode(digit)
            current = current.next
            
            if l1:
                l1 = l1.next
            if l2:
                l2 = l2.next
                
        return dummy.next

# %%
# Helpers to build and print linked list for local testing purpose
def build_list(arr):
    dummy = ListNode(0)
    current = dummy
    for num in arr:
        current.next = ListNode(num)
        current = current.next
    return dummy.next

def print_list(node):
    res = []
    while node:
        res.append(node.val)
        node = node.next
    print(res)

# %%
l1 = build_list([9,9,9])
l2 = build_list([1])
# Expected: [0,0,0,1]

sol = Solution()
head = sol.addTwoNumbers(l1, l2)

print_list(head)
# Out:
# [0, 0, 0, 1]

# %% [markdown]
# ## Linked List revision/exploration

# %%
# Linked list revision

class ListNode:
    def __init__(self, value=0, next=None):
        self.value = value
        self.next = next

# %%
# Assign values to each node
node1 = ListNode(2)
node2 = ListNode(7)
node3 = ListNode(11)

# Point to next node starting from head
node1.next = node2
node2.next = node3

# %%
node1.next.next.value
# Out:
# 11

# %%
node3.next is None
# Out:
# True

# %%
nums = [2,7,11]
dummy = ListNode(0)
current = dummy

for val in nums:
    current.next = ListNode(val)
    current = current.next

head = dummy.next

# %% [markdown]
# ## Assuming both inputs are list iterable and equal in length (Not the solution for problem)

# %%
# Definition for singly-linked list.
class ListNode(object):
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
        
class Solution(object):
    def addTwoNumbers(self, l1, l2):
        """
        :type l1: Optional[ListNode]
        :type l2: Optional[ListNode]
        :rtype: Optional[ListNode]
        """
        l3 = []
        carry = 0
        # l1 = l1[::-1]
        print(l1)
        # l2 = l2[::-1]
        print(l2, "\n\n")
        
        for x,y in zip(l1,l2):
            print(x, y)
            total = x+y+carry
            print(f'total: {total}')
            
            if 10 <= total:
                digit = total % 10
                carry = total // 10
                
                l3.append(digit)
                # digits = [int(d) for d in str(total)]
                # print("Carry will be added", digits)
                
                # l3.append(digits[1])
                # carry = digits[0]
            else:
                l3.append(total)
                print(l3, '\n')
                
        
        return l3

# %%
solution = Solution()
solution.addTwoNumbers([2,4,3], [5,6,4])
# Out:
# [2, 4, 3]
# [5, 6, 4]
#
#
# 2 5
# total: 7
# [7]
#
# 4 6
# total: 10
# 3 4
# total: 8
# [7, 0, 8]
# [7, 0, 8]

# %%
l1, l2 =[2,4,3], [5,6,4]

[x+y for x,y in zip(l1,l2)]
# Out:
# [7, 10, 7]
